# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# comment this out if not using jupyter notebook in dark mode
from matplotlib import style
print(plt.style.available)
style.use('seaborn')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\tanmay\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
data = pd.read_excel('Z:/datasets/Sales Data.xlsx', engine='openpyxl')

# %%
data.head()
# Out:
#                                                title  listed_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...         16.00
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress          8.00
# 2  2020 New Arrival Women Spring and Summer Beach...          8.00
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...          8.00
# 4  Women Summer Shorts Lace Up Elastic Waistband ...          2.72
#
#    retail_price currency_buyer  units_sold  uses_ad_boosts  rating  \
# 0            14            EUR         100               0    3.76
# 1            22            EUR       20000               1    3.45
# 2            43            EUR         100               0    3.57
# 3             8            EUR        5000               1    4.03
# 4             3            EUR         100               1    3.10
#
#    rating_count  rating_five_count  rating_four_count  ...  \
# 0            54               26.0                8.0  ...
# ...

# %%
data.describe()
# Out:
#        listed_price  retail_price     units_sold  uses_ad_boosts       rating  \
# count   1573.000000   1573.000000    1573.000000     1573.000000  1573.000000
# mean       8.325372     23.288620    4339.005086        0.432931     3.820896
# std        3.932030     30.357863    9356.539302        0.495639     0.515374
# min        1.000000      1.000000       1.000000        0.000000     1.000000
# 25%        5.810000      7.000000     100.000000        0.000000     3.550000
# 50%        8.000000     10.000000    1000.000000        0.000000     3.850000
# 75%       11.000000     26.000000    5000.000000        1.000000     4.110000
# max       49.000000    252.000000  100000.000000        1.000000     5.000000
#
#        rating_count  rating_five_count  rating_four_count  rating_three_count  \
# count   1573.000000        1528.000000        1528.000000         1528.000000
# mean     889.659250         442.263743         179.599476          134.549738
# ...

# %%
data.columns
# Out:
# Index(['title', 'listed_price', 'retail_price', 'currency_buyer', 'units_sold',
#        'uses_ad_boosts', 'rating', 'rating_count', 'rating_five_count',
#        'rating_four_count', 'rating_three_count', 'rating_two_count',
#        'rating_one_count', 'badges_count', 'badge_local_product',
#        'badge_product_quality', 'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'origin_country',
#        'merchant_rating_count', 'merchant_rating', 'product_id'],
#       dtype='object')

# %%
data.drop(columns=['title','currency_buyer','uses_ad_boosts'],inplace=True)

# %%
data.drop(columns=['badges_count','badge_local_product','badge_product_quality','badge_fast_shipping','tags'],inplace=True)

# %%
data.drop(columns=['shipping_is_express'],inplace=True)

# %%
data.head()
# Out:
#    listed_price  retail_price  units_sold  rating  rating_count  \
# 0         16.00            14         100    3.76            54
# 1          8.00            22       20000    3.45          6135
# 2          8.00            43         100    3.57            14
# 3          8.00             8        5000    4.03           579
# 4          2.72             3         100    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count  ... product_variation_size_id  \
# 0               9.0  ...                         M
# ...

# %%
data.isnull().sum()
# Out:
# listed_price                      0
# retail_price                      0
# units_sold                        0
# rating                            0
# rating_count                      0
# rating_five_count                45
# rating_four_count                45
# rating_three_count               45
# rating_two_count                 45
# rating_one_count                 45
# product_color                    41
# product_variation_size_id        14
# product_variation_inventory       0
# shipping_option_price             0
# countries_shipped_to              0
# inventory_total                   0
# has_urgency_banner             1100
# origin_country                   17
# merchant_rating_count             0
# merchant_rating                   0
# product_id                        0
# dtype: int64

# %%
data.drop(columns=['has_urgency_banner'],inplace=True)
data.head()
# Out:
#    listed_price  retail_price  units_sold  rating  rating_count  \
# 0         16.00            14         100    3.76            54
# 1          8.00            22       20000    3.45          6135
# 2          8.00            43         100    3.57            14
# 3          8.00             8        5000    4.03           579
# 4          2.72             3         100    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count product_color product_variation_size_id  \
# ...

# %%
data.drop(columns=['origin_country'],inplace=True)
data.head()
# Out:
#    listed_price  retail_price  units_sold  rating  rating_count  \
# 0         16.00            14         100    3.76            54
# 1          8.00            22       20000    3.45          6135
# 2          8.00            43         100    3.57            14
# 3          8.00             8        5000    4.03           579
# 4          2.72             3         100    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count product_color product_variation_size_id  \
# ...

# %%
data.isnull().sum()
# Out:
# listed_price                    0
# retail_price                    0
# units_sold                      0
# rating                          0
# rating_count                    0
# rating_five_count              45
# rating_four_count              45
# rating_three_count             45
# rating_two_count               45
# rating_one_count               45
# product_color                  41
# product_variation_size_id      14
# product_variation_inventory     0
# shipping_option_price           0
# countries_shipped_to            0
# inventory_total                 0
# merchant_rating_count           0
# merchant_rating                 0
# product_id                      0
# dtype: int64

# %%
data.drop(columns=['product_variation_size_id'],inplace=True)
data.head()
# Out:
#    listed_price  retail_price  units_sold  rating  rating_count  \
# 0         16.00            14         100    3.76            54
# 1          8.00            22       20000    3.45          6135
# 2          8.00            43         100    3.57            14
# 3          8.00             8        5000    4.03           579
# 4          2.72             3         100    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count product_color  product_variation_inventory  \
# ...

# %%
data.drop(columns=['product_color'],inplace=True)
data.head()
# Out:
#    listed_price  retail_price  units_sold  rating  rating_count  \
# 0         16.00            14         100    3.76            54
# 1          8.00            22       20000    3.45          6135
# 2          8.00            43         100    3.57            14
# 3          8.00             8        5000    4.03           579
# 4          2.72             3         100    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count  product_variation_inventory  shipping_option_price  \
# ...

# %%
data.head()
# Out:
#    listed_price  retail_price  units_sold  rating  rating_count  \
# 0         16.00            14         100    3.76            54
# 1          8.00            22       20000    3.45          6135
# 2          8.00            43         100    3.57            14
# 3          8.00             8        5000    4.03           579
# 4          2.72             3         100    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count  product_variation_inventory  shipping_option_price  \
# ...

# %%
data.isnull().sum()
# Out:
# listed_price                    0
# retail_price                    0
# units_sold                      0
# rating                          0
# rating_count                    0
# rating_five_count              45
# rating_four_count              45
# rating_three_count             45
# rating_two_count               45
# rating_one_count               45
# product_variation_inventory     0
# shipping_option_price           0
# countries_shipped_to            0
# inventory_total                 0
# merchant_rating_count           0
# merchant_rating                 0
# product_id                      0
# dtype: int64

# %%
data['rating_five_count'] = data['rating_five_count'].replace(np.nan, 0)

# %%
data.isnull().sum()
# Out:
# listed_price                    0
# retail_price                    0
# units_sold                      0
# rating                          0
# rating_count                    0
# rating_five_count               0
# rating_four_count              45
# rating_three_count             45
# rating_two_count               45
# rating_one_count               45
# product_variation_inventory     0
# shipping_option_price           0
# countries_shipped_to            0
# inventory_total                 0
# merchant_rating_count           0
# merchant_rating                 0
# product_id                      0
# dtype: int64

# %%
data['rating_four_count'] = data['rating_four_count'].replace(np.nan, 0)
data['rating_three_count'] = data['rating_three_count'].replace(np.nan, 0)
data['rating_two_count'] = data['rating_two_count'].replace(np.nan, 0)
data['rating_one_count'] = data['rating_one_count'].replace(np.nan, 0)

# %%
data.isnull().sum()
# Out:
# listed_price                   0
# retail_price                   0
# units_sold                     0
# rating                         0
# rating_count                   0
# rating_five_count              0
# rating_four_count              0
# rating_three_count             0
# rating_two_count               0
# rating_one_count               0
# product_variation_inventory    0
# shipping_option_price          0
# countries_shipped_to           0
# inventory_total                0
# merchant_rating_count          0
# merchant_rating                0
# product_id                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listed_price                 1573 non-null   float64
#  1   retail_price                 1573 non-null   int64
#  2   units_sold                   1573 non-null   int64
#  3   rating                       1573 non-null   float64
#  4   rating_count                 1573 non-null   int64
#  5   rating_five_count            1573 non-null   float64
#  6   rating_four_count            1573 non-null   float64
#  7   rating_three_count           1573 non-null   float64
#  8   rating_two_count             1573 non-null   float64
#  9   rating_one_count             1573 non-null   float64
#  10  product_variation_inventory  1573 non-null   int64
#  11  shipping_option_price        1573 non-null   int64
#  12  countries_shipped_to         1573 non-null   int64
# ...

# %%
correlation = data.corr()

# %%
plt.subplots(figsize=(27,7))
heatmap = sns.heatmap(correlation,vmin=-1,vmax=1,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['units_sold'], axis = 1)
y = data['units_sold']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2,random_state = 365)

# %% [markdown]
# ### create regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

k = model.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
#Accuracy
r2_score(y_test,y_pred)
# Out:
# 0.7384113109123878

# %%
# Accuracy = 0.7384
